# %% [markdown]
# <a href="https://colab.research.google.com/github/DinRazar/ispm/blob/main/%D0%A0%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Задание №1. Определение концептуальных основ дипломного проекта в области информационных систем**

# %% [markdown]
# В рамках дисциплины "Управление проектами информационных систем" представьте развернутое концептуальное обоснование вашего проекта, ответив на следующие вопросы:

# %% [markdown]
# #### **1. Обоснование необходимости разработки**

# %% [markdown]
# Для кого предназначено разрабатываемое Вами решение и какие потребности целевой аудитории оно призвано удовлетворить?

# %% [markdown]
# *Обоснуйте актуальность решаемой проблемы для конкретных заинтересованных сторон.*

# %% [markdown]
# Разрабатываемое решение предназначено для специалистов, работающих с пространственными данными: исследователей в области экологии и географии, студентов профильных направлений, а также для широкого круга пользователей, заинтересованных в анализе состояния природных территорий. Основная потребность заключается в получении актуальной информации о типах земного покрытия — где находится снежный покров, водные объекты, лесные массивы, гари или обнажённый грунт.
#
# Существующие подходы к анализу спутниковых снимков имеют существенное ограничение: большинство моделей работают только с оптическими изображениями. В условиях высокой облачности, характерной для многих регионов России, а также в период полярной ночи такие модели становятся бесполезными. Отсутствие инструментов, способных эффективно обрабатывать данные в любых погодных условиях, затрудняет проведение непрерывного мониторинга территорий.

# %% [markdown]
# ---

# %% [markdown]
# #### **2. Ожидаемые результаты проекта**

# %% [markdown]
# Опишите конкретные результаты, которые планируется получить по завершении проекта. Какой программный продукт, методика или информационная система будет создан/создана в результате вашей работы?

# %% [markdown]
# В рамках работы планируется получить следующие результаты.
#
# Адаптированная мультимодальная модель на основе архитектуры MaRS, обученная совместно на оптических и радарных спутниковых снимках. Модель будет классифицировать земное покрытие по пяти категориям: вода, снег, растительность, гарь, обнажённый грунт.
#
# Прогностический модуль на основе рекуррентных нейронных сетей, позволяющий отслеживать изменения во времени и формировать краткосрочные прогнозы динамики земного покрытия.
#
# Веб-приложение с интерактивной картой, предоставляющее доступ к результатам анализа без необходимости использования специализированного программного обеспечения.
#
# Набор размеченных данных спутниковых снимков для выбранного региона, пригодный для дальнейших исследований и дообучения моделей.

# %% [markdown]
# ---

# %% [markdown]
# #### **3. Методология использования**

# %% [markdown]
# Каким образом предполагается практическое применение разрабатываемого решения? Опишите основные сценарии взаимодействия пользователей с разрабатываемым решением.

# %% [markdown]
# Взаимодействие с разрабатываемым решением организовано через веб-интерфейс. Пользователь выбирает интересующую территорию на интерактивной карте. Система отображает текущее состояние земного покрытия, выделяя различные типы объектов цветовыми маркерами.
#
# Доступен просмотр временных рядов: можно увидеть, как изменялась ситуация на выбранном участке за предыдущие периоды. Для этого используются накопленные данные спутниковых наблюдений.
#
# Прогностический модуль позволяет ознакомиться с предполагаемыми изменениями на ближайшие дни или недели. Все результаты представлены в визуальной форме, также предусмотрена возможность выгрузки данных для дальнейшего анализа.

# %% [markdown]
# ---

# %% [markdown]
# #### **4. Входные данные и их источники**

# %% [markdown]
# Какие типы данных будут использоваться в качестве входных данных для вашего решения? В каком формате они будут представлены и из каких источников планируется их получение?

# %% [markdown]
# В качестве входных данных используются два типа спутниковых снимков.
#
# Оптические изображения поступают со спутников Sentinel-2 и Landsat. Эти данные предоставляют информацию о спектральных характеристиках объектов и позволяют визуально идентифицировать различные типы земного покрытия. Источник — открытые архивы Европейского космического агентства и NASA.
#
# Радарные изображения поступают со спутника Sentinel-1. Данный тип съёмки не зависит от освещённости и облачности, что обеспечивает возможность мониторинга в любых метеоусловиях. Используются данные с вертикальной и горизонтальной поляризацией в формате Ground Range Detected.

# %% [markdown]
# ---

# %% [markdown]
# #### **5. Выходные данные и практическая значимость**

# %% [markdown]
# Какие результаты будет формировать Ваше решение на выходе?

# %% [markdown]
# На выходе система формирует карту земного покрытия в формате, пригодном для визуализации на веб-карте и для выгрузки в виде растрового изображения. Также предоставляются временные графики изменения площадей различных типов покрытия за выбранный период и прогнозные карты на заданный горизонт.
#
# Практическая значимость заключается в создании доступного инструмента для работы со спутниковыми данными, не требующего от пользователя навыков программирования или владения сложными геоинформационными системами. Решение позволяет вести непрерывный мониторинг территорий независимо от погодных условий, что особенно важно для регионов с высокой облачностью. Возможность просмотра временных рядов и формирования прогнозов расширяет функциональность по сравнению с существующими открытыми решениями. Собранный в ходе работы набор размеченных данных может быть использован для дальнейших исследований и дообучения моделей в области дистанционного зондирования Земли.

# %% [markdown]
# ---
